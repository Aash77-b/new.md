# %%
import numpy as np
num=[1,2,3,4,5]
kind=np.array(num)
kind
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.mean(num)
# Out:
# np.float64(3.0)

# %%
np.max(num)
# Out:
# np.int64(5)

# %%
np.sum(num)
# Out:
# np.int64(15)
